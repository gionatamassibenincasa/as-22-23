% %% [markdown]
% # Approssimazione numerica della funzione derivata

% %% [markdown]
% La definizione classica della derivata di una funzione $f$ in un punto $x_0$ interno al domino è:
%
% $$f^\prime (x_0) = \frac{ f(x + h) - f(x)}{h}$$
%
% Vedere anche https://observablehq.com/@gionatamassi-sb/derivazione-numerica
